# %%
# Let us use a Nifti file that is shipped with nilearn
from nilearn.datasets import MNI152_FILE_PATH

# Note that the variable MNI152_FILE_PATH is just a path to a Nifti file
print('Path to MNI152 template: %r' % MNI152_FILE_PATH)
# Out:
# Path to MNI152 template: '/home/william/vsc_projects/nilearn/nilearn/nilearn/datasets/data/mni_icbm152_t1_tal_nlin_sym_09a_converted.nii.gz'
# /home/william/vsc_projects/nilearn/nilearn/nilearn/datasets/__init__.py:93: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   warn("Fetchers from the nilearn.datasets module will be "

# %%
from nilearn import plotting
plotting.plot_img(MNI152_FILE_PATH)

# %%
from nilearn import image
smooth_anat_img = image.smooth_img(MNI152_FILE_PATH, fwhm=3)

# While we are giving a file name as input, the function returns
# an in-memory object:
smooth_anat_img

# %%
plotting.plot_img(smooth_anat_img)

# %%
more_smooth_anat_img = image.smooth_img(smooth_anat_img, fwhm=3)
plotting.plot_img(more_smooth_anat_img)

# %%
more_smooth_anat_img.to_filename('more_smooth_anat_img.nii.gz')

# %%
plotting.show()

# %%
#https://nilearn.github.io/auto_examples/plot_nilearn_101.html#sphx-glr-auto-examples-plot-nilearn-101-py
